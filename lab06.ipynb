# %%
import numpy as np
import math
from scipy.integrate import odeint
import matplotlib.pyplot as plt
a= 0.01
b= 0.02
N=6730
I0=46
R0=8
S0=N-I0-R0
t0 = 0
tmax = 200
dt = 0.01
def dy(s,t):
    dy1 =  0
    dy2 =  -b*s[1]
    dy3 = b*s[1]
    return [dy1, dy2, dy3]
t = np.arange(t0,tmax,dt) 
v0=[S0, I0, R0]
s = odeint(dy,v0,t)

# %%
plt.plot(t,s[:,0],'r', linewidth=2.0,label="S(t)")
plt.plot(t,s[:,1],'b', linewidth=2.0,label="I(t)")
plt.plot(t,s[:,2],'g', linewidth=2.0,label="R(t)")
plt.legend()
plt.grid()
plt.show()

# %%
def dy(s,t):
    dy1 =  -a*s[0]
    dy2 =  a*s[0]-b*s[1]
    dy3 = b*s[1]
    return [dy1, dy2, dy3]
t = np.arange(t0,tmax,dt) 
v0=[S0, I0, R0]
s = odeint(dy,v0,t)

# %%
plt.plot(t,s[:,0],'r', linewidth=2.0,label="S(t)")
plt.plot(t,s[:,1],'b', linewidth=2.0,label="I(t)")
plt.plot(t,s[:,2],'g', linewidth=2.0,label="R(t)")
plt.legend()
plt.grid()
plt.show()
